# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("/content/mental_health_social_media_dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   person_name                  5000 non-null   object
#  1   age                          5000 non-null   int64
#  2   date                         5000 non-null   object
#  3   gender                       5000 non-null   object
#  4   platform                     5000 non-null   object
#  5   daily_screen_time_min        5000 non-null   int64
#  6   social_media_time_min        5000 non-null   int64
#  7   negative_interactions_count  5000 non-null   int64
#  8   positive_interactions_count  5000 non-null   int64
#  9   sleep_hours                  5000 non-null   float64
#  10  physical_activity_min        5000 non-null   int64
#  11  anxiety_level                5000 non-null   int64
#  12  stress_level                 5000 non-null   int64
# ...

# %%
df.sample(10)
# Out:
#          person_name  age        date  gender   platform  \
# 3064      Riya Joshi   19   9/16/2025  Female  Instagram
# 891      Aadhya Nair   40    3/9/2025    Male     TikTok
# 979    Isha Deshmukh   27    9/6/2025    Male   WhatsApp
# 2449    Ishaan Gupta   64    6/8/2024    Male   WhatsApp
# 3053  Shaurya Sharma   23   8/22/2025    Male   Facebook
# 2756     Sonal Naidu   42   2/14/2024  Female   WhatsApp
# 1186      Riya Naidu   15  11/13/2024    Male    Twitter
# 1968       Arjun Das   28   6/21/2025  Female    YouTube
# 384       Avni Patel   17   4/14/2024  Female     TikTok
# 3113     Payal Reddy   30    2/9/2024  Female     TikTok
#
#       daily_screen_time_min  social_media_time_min  \
# 3064                    496                    248
# 891                     273                    177
# 979                     368                     92
# 2449                    171                     43
# 3053                    473                    166
# ...

# %%
def unique_values(df):
    skip_cols = ["person_name", "date"]   # columns you want to ignore

    for column in df.columns:
        if column in skip_cols:
            continue  # skip this column

        print(f"Unique values for column '{column}':")
        print(df[column].unique())
        print()

# %%
unique_values(df)
# Out:
# Unique values for column 'age':
# [35 24 26 66 31 25 29 28 39 33 30 42 34 22 36 51 19 63 13 64 67 17 40 23
#  32 16 50 21 38 53 43 20 65 45 54 27 18 59 61 15 14 57 69 37 47 55 60 49
#  41 48 58 52 56 44 62 68 46]
#
# Unique values for column 'gender':
# ['Male' 'Female' 'Other']
#
# Unique values for column 'platform':
# ['Instagram' 'Snapchat' 'Facebook' 'WhatsApp' 'TikTok' 'YouTube' 'Twitter']
#
# Unique values for column 'daily_screen_time_min':
# [320 453 357 190 383 516 328 394 326 339 230 363 376 387 223 500 456 349
#  362 375 493 266 219 449 162 355 366 382 335 468 481 254 179 492 205 518
#  396 472 269 405 238 515 338 351 435 208 331 404 237 488 204 457 494 398
#  330 354 427 391 467 180 444 517 329 340 497 270 370 446 459 412 245 258
#  483 496 381 154 400 212 225 478 476 249 393 469 482 386 222 499 455 252
#  505 401 485 498 271 201 251 395 147 471 268 213 226 479 224 477 490 501
#  454 397 470 436 374 507 520 210 343 356 489 367 203 360 209 473 246 450
# ...

# %%
def value_count(df):
    skip_cols = ["person_name", "date","physical_activity_min","age","sleep_hours"]
    for column in df.columns:
        if column in skip_cols:
            continue

        print(f"Value counts for column '{column}':")
        print(df[column].value_counts())

# %%
value_count(df)
# Out:
# Value counts for column 'gender':
# gender
# Female    2474
# Male      2427
# Other       99
# Name: count, dtype: int64
# Value counts for column 'platform':
# platform
# Facebook     744
# TikTok       723
# YouTube      716
# WhatsApp     710
# Snapchat     705
# Instagram    703
# Twitter      699
# Name: count, dtype: int64
# Value counts for column 'daily_screen_time_min':
# daily_screen_time_min
# 460    41
# 448    37
# 441    36
# 458    35
# 459    34
#        ..
# 188     3
# 193     3
# 412     3
# 402     2
# 184     2
# Name: count, Length: 342, dtype: int64
# Value counts for column 'social_media_time_min':
# social_media_time_min
# 112    50
# 128    46
# 120    40
# 116    38
# 182    38
#        ..
# 35      1
# 40      1
# 39      1
# 44      1
# 338     1
# Name: count, Length: 304, dtype: int64
# Value counts for column 'negative_interactions_count':
# negative_interactions_count
# 1    3367
# 0    1156
# 2     477
# Name: count, dtype: int64
# ...

# %%
df.describe()
# Out:
#                age  daily_screen_time_min  social_media_time_min  \
# count  5000.000000            5000.000000            5000.000000
# mean     29.947800             373.058200             175.331600
# std      12.279936             106.003916              71.209329
# min      13.000000             140.000000              35.000000
# 25%      21.000000             310.000000             118.000000
# 50%      27.000000             388.000000             170.000000
# 75%      35.250000             461.000000             231.000000
# max      69.000000             520.000000             338.000000
#
#        negative_interactions_count  positive_interactions_count  sleep_hours  \
# count                  5000.000000                  5000.000000  5000.000000
# mean                      0.864200                     1.835400     7.134660
# std                       0.555176                     0.943443     0.533184
# ...

# %%
corr = df.corr(numeric_only=True)
corr
# Out:
#                                   age  daily_screen_time_min  \
# age                          1.000000              -0.867197
# daily_screen_time_min       -0.867197               1.000000
# social_media_time_min       -0.591235               0.680839
# negative_interactions_count -0.422186               0.457361
# positive_interactions_count -0.450397               0.524203
# sleep_hours                  0.864386              -0.998553
# physical_activity_min        0.866304              -0.999627
# anxiety_level               -0.567443               0.629185
# stress_level                -0.748259               0.835955
# mood_level                   0.601122              -0.694937
#
#                              social_media_time_min  \
# age                                      -0.591235
# daily_screen_time_min                     0.680839
# social_media_time_min                     1.000000
# negative_interactions_count               0.760760
# ...

# %%
corr = df.corr(numeric_only=True)
plt.figure(figsize=(12,8))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %%
sns.histplot(df['daily_screen_time_min'], kde=True, palette='pastel')
# Out:
# /tmp/ipython-input-3918077864.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df['daily_screen_time_min'], kde=True, palette='pastel')
# <Axes: xlabel='daily_screen_time_min', ylabel='Count'>

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='platform', y='daily_screen_time_min',palette="pastel")
# Out:
# /tmp/ipython-input-3749356135.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='platform', y='daily_screen_time_min',palette="pastel")
# <Axes: xlabel='platform', ylabel='daily_screen_time_min'>

# %%
plt.figure(figsize=(10, 6))
df['date'] = pd.to_datetime(df['date'])
df.sort_values('date', inplace=True)

sns.lineplot(x='date', y='stress_level', data=df)
# Out:
# <Axes: xlabel='date', ylabel='stress_level'>

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='daily_screen_time_min', y='anxiety_level', data=df)
# Out:
# <Axes: xlabel='daily_screen_time_min', ylabel='anxiety_level'>

# %%
sns.pairplot(df[['sleep_hours','stress_level','anxiety_level','mood_level']])

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=df, x='gender', y='mood_level')
# Out:
# <Axes: xlabel='gender', ylabel='mood_level'>

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='platform')
# Out:
# <Axes: xlabel='platform', ylabel='count'>

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='platform', y='mood_level')
# Out:
# <Axes: xlabel='platform', ylabel='mood_level'>
