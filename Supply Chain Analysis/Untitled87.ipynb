# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/ev_vs_petrol_dataset_v3.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   country                        1200 non-null   object
#  1   region                         1200 non-null   object
#  2   year                           1200 non-null   int64
#  3   vehicle_segment                1200 non-null   object
#  4   powertrain_type                1200 non-null   object
#  5   ev_sales                       1200 non-null   int64
#  6   petrol_car_sales               1200 non-null   int64
#  7   diesel_car_sales               1200 non-null   int64
#  8   total_vehicle_sales            1200 non-null   int64
#  9   ev_market_share                1200 non-null   float64
#  10  charging_stations              1200 non-null   int64
#  11  fast_chargers_share            1200 non-null   float64
#  12  avg_ev_range_km                1200 non-null   int64
#  13  fuel_price_usd_per_liter       1200 non-null   float64
#  14  electricity_price_usd_per_kwh  1200 non-null   float64
#  15  gdp_per_capita                 1200 non-null   int64
#  16  urban_population_percent       1200 non-null   float64
#  17  co2_emissions_transport_mt     1200 non-null   float64
#  18  ev_subsidy_usd                 1200 non-null   int64
#  19  emission_regulation_score      1200 non-null   float64
#  20  ev_growth_rate_yoy             1200 non-null   float64
#  21  is_ev_dominant                 1200 non-null   int64
# dtypes: float64(8), int64(10), object(4)
# memory usage: 206.4+ KB

# %%
df.head()
# Out:
#      country   region  year vehicle_segment powertrain_type  ev_sales  \
# 0  Australia  Oceania  2010      commercial             ICE         5
# 1  Australia  Oceania  2010     mass_market             ICE        57
# 2  Australia  Oceania  2010         premium             ICE        37
# 3  Australia  Oceania  2011      commercial             ICE        11
# 4  Australia  Oceania  2011     mass_market             ICE       129
#
#    petrol_car_sales  diesel_car_sales  total_vehicle_sales  ev_market_share  \
# 0             92877             61921               154803             0.00
# 1            535933             73089               609079             0.01
# 2            235282             20462               255781             0.01
# 3             98092             65395               163498             0.01
# 4            569679             77684               647492             0.02
#
#    ...  avg_ev_range_km  fuel_price_usd_per_liter  \
# 0  ...              124                      1.09
# 1  ...              124                      1.09
# 2  ...              124                      1.09
# 3  ...              133                      1.09
# 4  ...              133                      1.09
#
#    electricity_price_usd_per_kwh  gdp_per_capita  urban_population_percent  \
# 0                          0.149           51977                      88.8
# 1                          0.149           51977                      88.8
# 2                          0.149           51977                      88.8
# 3                          0.163           52807                      88.9
# 4                          0.163           52807                      88.9
#
#    co2_emissions_transport_mt  ev_subsidy_usd  emission_regulation_score  \
# 0                        88.7               0                       30.4
# 1                        88.7               0                       30.4
# 2                        88.7               0                       30.4
# 3                        88.3               0                       30.8
# 4                        88.3               0                       30.8
#
#    ev_growth_rate_yoy  is_ev_dominant
# 0                0.00               0
# 1                0.00               0
# 2                0.00               0
# 3              120.00               0
# 4              126.32               0
#
# [5 rows x 22 columns]

# %%
df.describe().T
# Out:
#                                 count           mean           std  \
# year                           1200.0    2017.500000  4.611694e+00
# ev_sales                       1200.0   63602.364167  4.079506e+05
# petrol_car_sales               1200.0  773306.282500  1.756934e+06
# diesel_car_sales               1200.0  140936.883333  2.913472e+05
# total_vehicle_sales            1200.0  977845.530000  2.211799e+06
# ev_market_share                1200.0       6.327992  1.323172e+01
# charging_stations              1200.0   56938.980000  3.359383e+05
# fast_chargers_share            1200.0      14.437750  1.005753e+01
# avg_ev_range_km                1200.0     265.872500  1.219941e+02
# fuel_price_usd_per_liter       1200.0       1.342239  3.634615e-01
# electricity_price_usd_per_kwh  1200.0       0.169508  7.929844e-02
# gdp_per_capita                 1200.0   35651.525000  2.389901e+04
# urban_population_percent       1200.0      74.609000  1.485881e+01
# co2_emissions_transport_mt     1200.0     190.837000  3.631006e+02
# ev_subsidy_usd                 1200.0    2910.940000  2.477307e+03
# emission_regulation_score      1200.0      58.761860  2.009287e+01
# ev_growth_rate_yoy             1200.0      64.002958  7.138680e+01
# is_ev_dominant                 1200.0       0.018333  1.342097e-01
#
#                                        min           25%         50%  \
# year                            2010.00000    2013.75000    2017.500
# ev_sales                           5.00000     200.25000    2731.500
# petrol_car_sales                1727.00000   88705.00000  229478.500
# diesel_car_sales                 150.00000   19510.75000   51361.000
# total_vehicle_sales            17480.00000  130046.50000  290513.000
# ev_market_share                    0.00000       0.07750       0.830
# charging_stations                  0.00000     491.75000    4090.000
# fast_chargers_share                0.00000       6.00000      12.900
# avg_ev_range_km                  106.00000     150.00000     238.500
# fuel_price_usd_per_liter           0.48290       1.09700       1.352
# electricity_price_usd_per_kwh      0.06699       0.09875       0.158
# gdp_per_capita                  1359.00000   11077.25000   37329.000
# urban_population_percent          30.90000      64.17500      79.900
# co2_emissions_transport_mt         5.40000      30.17500      94.250
# ev_subsidy_usd                     0.00000       0.00000    2794.500
# emission_regulation_score         19.48400      43.60000      59.350
# ev_growth_rate_yoy               -40.96000      16.37250      44.165
# is_ev_dominant                     0.00000       0.00000       0.000
#
#                                         75%           max
# year                             2021.25000  2.025000e+03
# ev_sales                        19905.00000  7.670056e+06
# petrol_car_sales               638532.00000  1.477369e+07
# diesel_car_sales               111191.00000  2.014595e+06
# total_vehicle_sales            762448.25000  1.884998e+07
# ev_market_share                     5.83250  9.500000e+01
# charging_stations               22518.00000  4.338106e+06
# fast_chargers_share                20.95000  4.930000e+01
# avg_ev_range_km                   380.25000  5.070000e+02
# fuel_price_usd_per_liter            1.56850  2.153000e+00
# electricity_price_usd_per_kwh       0.22025  3.790400e-01
# gdp_per_capita                  50930.00000  1.034370e+05
# urban_population_percent           84.07500  9.850000e+01
# co2_emissions_transport_mt        159.57500  1.900800e+03
# ev_subsidy_usd                   4973.75000  8.952000e+03
# emission_regulation_score          74.82500  9.560200e+01
# ev_growth_rate_yoy                 80.90750  3.000000e+02
# is_ev_dominant                      0.00000  1.000000e+00

# %%
num_col = df.select_dtypes(include = "number").columns
df[num_col].corr()
# Out:
#                                    year  ev_sales  petrol_car_sales  \
# year                           1.000000  0.177751         -0.010944
# ev_sales                       0.177751  1.000000          0.442192
# petrol_car_sales              -0.010944  0.442192          1.000000
# diesel_car_sales              -0.002767  0.341708          0.819367
# total_vehicle_sales            0.023727  0.580707          0.983835
# ev_market_share                0.485004  0.241799         -0.035446
# charging_stations              0.191127  0.815722          0.339900
# fast_chargers_share            0.775148  0.326915          0.275110
# avg_ev_range_km                0.974625  0.186394         -0.022251
# fuel_price_usd_per_liter       0.387946 -0.006191         -0.269433
# electricity_price_usd_per_kwh  0.270683 -0.059668         -0.190309
# gdp_per_capita                 0.113194 -0.041702         -0.097247
# urban_population_percent       0.087381 -0.041628         -0.113989
# co2_emissions_transport_mt     0.006772  0.244213          0.652529
# ev_subsidy_usd                 0.189137 -0.008986          0.363074
# emission_regulation_score      0.549795  0.157687         -0.059426
# ev_growth_rate_yoy            -0.123429 -0.043434          0.025204
# is_ev_dominant                 0.159008  0.066136         -0.048336
#
#                                diesel_car_sales  total_vehicle_sales  \
# year                                  -0.002767             0.023727
# ev_sales                               0.341708             0.580707
# petrol_car_sales                       0.819367             0.983835
# diesel_car_sales                       1.000000             0.845610
# total_vehicle_sales                    0.845610             1.000000
# ev_market_share                       -0.080129             0.005887
# charging_stations                      0.409353             0.474374
# fast_chargers_share                    0.314081             0.320202
# avg_ev_range_km                       -0.014535             0.014789
# fuel_price_usd_per_liter              -0.291348            -0.253542
# electricity_price_usd_per_kwh         -0.208542            -0.189647
# gdp_per_capita                        -0.107346            -0.099079
# urban_population_percent              -0.125322            -0.114733
# co2_emissions_transport_mt             0.717290             0.657861
# ev_subsidy_usd                         0.391809             0.338360
# emission_regulation_score             -0.056115            -0.025512
# ev_growth_rate_yoy                     0.022684             0.014998
# is_ev_dominant                        -0.059596            -0.034048
#
#                                ev_market_share  charging_stations  \
# year                                  0.485004           0.191127
# ev_sales                              0.241799           0.815722
# petrol_car_sales                     -0.035446           0.339900
# diesel_car_sales                     -0.080129           0.409353
# total_vehicle_sales                   0.005887           0.474374
# ev_market_share                       1.000000           0.213751
# charging_stations                     0.213751           1.000000
# fast_chargers_share                   0.459142           0.387720
# avg_ev_range_km                       0.547451           0.198416
# fuel_price_usd_per_liter              0.553799           0.000687
# electricity_price_usd_per_kwh         0.214611          -0.088496
# gdp_per_capita                        0.411767          -0.086394
# urban_population_percent              0.175599          -0.059108
# co2_emissions_transport_mt           -0.078251           0.229138
# ev_subsidy_usd                       -0.055643          -0.036015
# emission_regulation_score             0.586525           0.183938
# ev_growth_rate_yoy                   -0.188102          -0.052530
# is_ev_dominant                        0.711081           0.071177
#
#                                fast_chargers_share  avg_ev_range_km  \
# year                                      0.775148         0.974625
# ev_sales                                  0.326915         0.186394
# petrol_car_sales                          0.275110        -0.022251
# diesel_car_sales                          0.314081        -0.014535
# total_vehicle_sales                       0.320202         0.014789
# ev_market_share                           0.459142         0.547451
# charging_stations                         0.387720         0.198416
# fast_chargers_share                       1.000000         0.769471
# avg_ev_range_km                           0.769471         1.000000
# fuel_price_usd_per_liter                  0.233524         0.480050
# electricity_price_usd_per_kwh             0.019044         0.324591
# gdp_per_capita                            0.152895         0.196629
# urban_population_percent                  0.087763         0.129158
# co2_emissions_transport_mt                0.193610         0.004145
# ev_subsidy_usd                            0.283161         0.173836
# emission_regulation_score                 0.532301         0.608046
# ev_growth_rate_yoy                       -0.093746        -0.136242
# is_ev_dominant                            0.197703         0.191728
#
#                                fuel_price_usd_per_liter  \
# year                                           0.387946
# ev_sales                                      -0.006191
# petrol_car_sales                              -0.269433
# diesel_car_sales                              -0.291348
# total_vehicle_sales                           -0.253542
# ev_market_share                                0.553799
# charging_stations                              0.000687
# fast_chargers_share                            0.233524
# avg_ev_range_km                                0.480050
# fuel_price_usd_per_liter                       1.000000
# electricity_price_usd_per_kwh                  0.647238
# gdp_per_capita                                 0.523988
# urban_population_percent                       0.381877
# co2_emissions_transport_mt                    -0.396493
# ev_subsidy_usd                                 0.044266
# emission_regulation_score                      0.815719
# ev_growth_rate_yoy                            -0.084775
# is_ev_dominant                                 0.243861
#
#                                electricity_price_usd_per_kwh  gdp_per_capita  \
# year                                                0.270683        0.113194
# ev_sales                                           -0.059668       -0.041702
# petrol_car_sales                                   -0.190309       -0.097247
# diesel_car_sales                                   -0.208542       -0.107346
# total_vehicle_sales                                -0.189647       -0.099079
# ev_market_share                                     0.214611        0.411767
# charging_stations                                  -0.088496       -0.086394
# fast_chargers_share                                 0.019044        0.152895
# avg_ev_range_km                                     0.324591        0.196629
# fuel_price_usd_per_liter                            0.647238        0.523988
# electricity_price_usd_per_kwh                       1.000000        0.401405
# gdp_per_capita                                      0.401405        1.000000
# urban_population_percent                            0.356683        0.529244
# co2_emissions_transport_mt                         -0.204193        0.056169
# ev_subsidy_usd                                      0.162982        0.053124
# emission_regulation_score                           0.573428        0.662562
# ev_growth_rate_yoy                                 -0.088986       -0.092180
# is_ev_dominant                                     -0.039667        0.239767
#
#                                urban_population_percent  \
# year                                           0.087381
# ev_sales                                      -0.041628
# petrol_car_sales                              -0.113989
# diesel_car_sales                              -0.125322
# total_vehicle_sales                           -0.114733
# ev_market_share                                0.175599
# charging_stations                             -0.059108
# fast_chargers_share                            0.087763
# avg_ev_range_km                                0.129158
# fuel_price_usd_per_liter                       0.381877
# electricity_price_usd_per_kwh                  0.356683
# gdp_per_capita                                 0.529244
# urban_population_percent                       1.000000
# co2_emissions_transport_mt                    -0.017600
# ev_subsidy_usd                                 0.083308
# emission_regulation_score                      0.399606
# ev_growth_rate_yoy                            -0.073050
# is_ev_dominant                                 0.092095
#
#                                co2_emissions_transport_mt  ev_subsidy_usd  \
# year                                             0.006772        0.189137
# ev_sales                                         0.244213       -0.008986
# petrol_car_sales                                 0.652529        0.363074
# diesel_car_sales                                 0.717290        0.391809
# total_vehicle_sales                              0.657861        0.338360
# ev_market_share                                 -0.078251       -0.055643
# charging_stations                                0.229138       -0.036015
# fast_chargers_share                              0.193610        0.283161
# avg_ev_range_km                                  0.004145        0.173836
# fuel_price_usd_per_liter                        -0.396493        0.044266
# electricity_price_usd_per_kwh                   -0.204193        0.162982
# gdp_per_capita                                   0.056169        0.053124
# urban_population_percent                        -0.017600        0.083308
# co2_emissions_transport_mt                       1.000000        0.441392
# ev_subsidy_usd                                   0.441392        1.000000
# emission_regulation_score                       -0.111149        0.299521
# ev_growth_rate_yoy                              -0.028918        0.067655
# is_ev_dominant                                  -0.054011       -0.120855
#
#                                emission_regulation_score  ev_growth_rate_yoy  \
# year                                            0.549795           -0.123429
# ev_sales                                        0.157687           -0.043434
# petrol_car_sales                               -0.059426            0.025204
# diesel_car_sales                               -0.056115            0.022684
# total_vehicle_sales                            -0.025512            0.014998
# ev_market_share                                 0.586525           -0.188102
# charging_stations                               0.183938           -0.052530
# fast_chargers_share                             0.532301           -0.093746
# avg_ev_range_km                                 0.608046           -0.136242
# fuel_price_usd_per_liter                        0.815719           -0.084775
# electricity_price_usd_per_kwh                   0.573428           -0.088986
# gdp_per_capita                                  0.662562           -0.092180
# urban_population_percent                        0.399606           -0.073050
# co2_emissions_transport_mt                     -0.111149           -0.028918
# ev_subsidy_usd                                  0.299521            0.067655
# emission_regulation_score                       1.000000           -0.106492
# ev_growth_rate_yoy                             -0.106492            1.000000
# is_ev_dominant                                  0.234670           -0.092046
#
#                                is_ev_dominant
# year                                 0.159008
# ev_sales                             0.066136
# petrol_car_sales                    -0.048336
# diesel_car_sales                    -0.059596
# total_vehicle_sales                 -0.034048
# ev_market_share                      0.711081
# charging_stations                    0.071177
# fast_chargers_share                  0.197703
# avg_ev_range_km                      0.191728
# fuel_price_usd_per_liter             0.243861
# electricity_price_usd_per_kwh       -0.039667
# gdp_per_capita                       0.239767
# urban_population_percent             0.092095
# co2_emissions_transport_mt          -0.054011
# ev_subsidy_usd                      -0.120855
# emission_regulation_score            0.234670
# ev_growth_rate_yoy                  -0.092046
# is_ev_dominant                       1.000000
