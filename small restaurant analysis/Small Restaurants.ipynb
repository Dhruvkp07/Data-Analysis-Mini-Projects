# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('/content/world_top_restaurants_dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Restaurant_Name    50 non-null     object
#  1   City               50 non-null     object
#  2   Country            50 non-null     object
#  3   Cuisine_Type       50 non-null     object
#  4   Michelin_Stars     50 non-null     int64
#  5   Average_Price_USD  50 non-null     int64
#  6   Chef               50 non-null     object
#  7   Established_Year   50 non-null     int64
#  8   Seating_Capacity   50 non-null     int64
#  9   Rating             50 non-null     float64
#  10  Signature_Dish     50 non-null     object
#  11  Years_Operating    50 non-null     int64
#  12  Price_Category     50 non-null     object
#  13  Star_Category      50 non-null     object
#  14  Continent          50 non-null     object
# dtypes: float64(1), int64(5), object(9)
# ...

# %%
df.head()
# Out:
#        Restaurant_Name        City    Country          Cuisine_Type  \
# 0  Osteria Francescana      Modena      Italy  Italian Contemporary
# 1               Odette   Singapore  Singapore   French Contemporary
# 2   The French Laundry  Yountville        USA                French
# 3               Arpège       Paris     France     French Vegetarian
# 4              Mirazur      Menton     France         Mediterranean
#
#    Michelin_Stars  Average_Price_USD             Chef  Established_Year  \
# 0               3                320  Massimo Bottura              1995
# 1               3                320     Julien Royer              2008
# 2               3                390    Thomas Keller              1994
# 3               3                425    Alain Passard              1986
# 4               3                350  Mauro Colagreco              1991
#
#    Seating_Capacity  Rating           Signature_Dish  Years_Operating  \
# ...

# %%
def value_count(df):
  for i in df:
    print(df[i].value_counts())
    print('*'*100)

# %%
df['Michelin_Stars'].unique()
# Out:
# array([3, 2, 1, 0])

# %%
df[['Michelin_Stars', 'Rating']].corr()
# Out:
#                 Michelin_Stars    Rating
# Michelin_Stars        1.000000  0.656401
# Rating                0.656401  1.000000

# %%
value_count(df)
# Out:
# Restaurant_Name
# Osteria Francescana         1
# Odette                      1
# The French Laundry          1
# Arpège                      1
# Mirazur                     1
# Frantzén                    1
# Le Bernardin                1
# Piazza Duomo                1
# Arzak                       1
# Atelier Crenn               1
# Benu                        1
# Alléno Paris                1
# La Pergola                  1
# Quique Dacosta              1
# L'Astrance                  1
# El Celler de Can Roca       1
# Geranium                    1
# Eleven Madison Park         1
# Alinea                      1
# Le Calandre                 1
# Azurmendi                   1
# Ultraviolet                 1
# Noma                        1
# Den                         1
# SingleThread                1
# Restaurant Tim Raue         1
# Narisawa                    1
# Florilège                   1
# Steirereck                  1
# Momofuku Ko                 1
# ...

# %%
def unique(df):
  for i in df:
    print(df[i].unique())
    print('*'*100)

# %%
df.describe()
# Out:
#        Michelin_Stars  Average_Price_USD  Established_Year  Seating_Capacity  \
# count       50.000000           50.00000         50.000000          50.00000
# mean         1.920000          281.06000       2001.780000          41.96000
# std          1.192494          103.57811         17.962876          14.69966
# min          0.000000           85.00000       1897.000000          10.00000
# 25%          1.000000          212.50000       1998.500000          30.50000
# 50%          2.000000          282.50000       2006.500000          45.00000
# 75%          3.000000          323.75000       2010.750000          50.00000
# max          3.000000          570.00000       2017.000000          80.00000
#
#           Rating  Years_Operating
# count  50.000000        50.000000
# mean    4.702000        23.220000
# std     0.109712        17.962876
# min     4.500000         8.000000
# 25%     4.600000        14.250000
# 50%     4.700000        18.500000
# ...

# %%
unique(df)
# Out:
# ['Osteria Francescana' 'Odette' 'The French Laundry' 'Arpège' 'Mirazur'
#  'Frantzén' 'Le Bernardin' 'Piazza Duomo' 'Arzak' 'Atelier Crenn' 'Benu'
#  'Alléno Paris' 'La Pergola' 'Quique Dacosta' "L'Astrance"
#  'El Celler de Can Roca' 'Geranium' 'Eleven Madison Park' 'Alinea'
#  'Le Calandre' 'Azurmendi' 'Ultraviolet' 'Noma' 'Den' 'SingleThread'
#  'Restaurant Tim Raue' 'Narisawa' 'Florilège' 'Steirereck' 'Momofuku Ko'
#  'Restaurant André' 'Amber' 'Disfrutar' 'Mugaritz' 'Alchemist'
#  'Asador Etxebarri' 'The Clove Club' 'Burnt Ends' 'Septime' 'Central'
#  'Maido' 'Pujol' 'Gaggan Anand' 'Quintonil' 'Sühring' 'Boragó'
#  'Blue Hill at Stone Barns' 'White Rabbit' 'Leo' "Lyle's"]
# ****************************************************************************************************
# ['Modena' 'Singapore' 'Yountville' 'Paris' 'Menton' 'Stockholm' 'New York'
#  'Alba' 'San Sebastián' 'San Francisco' 'Rome' 'Dénia' 'Girona'
# ...

# %%
df.groupby('Cuisine_Type')['Rating'].mean().sort_values(ascending=False)
# Out:
# Cuisine_Type
# French Vegetarian         4.900000
# Italian Contemporary      4.900000
# French                    4.800000
# Contemporary French       4.800000
# Nordic Contemporary       4.800000
# French Seafood            4.800000
# Contemporary Peruvian     4.800000
# Italian Haute Cuisine     4.800000
# French Haute Cuisine      4.800000
# New Nordic                4.750000
# Italian                   4.750000
# Basque                    4.750000
# Mediterranean             4.733333
# Contemporary American     4.733333
# French Contemporary       4.725000
# Asian Fusion              4.700000
# Nikkei                    4.700000
# Austrian Contemporary     4.700000
# Contemporary Catalan      4.700000
# Basque Grill              4.700000
# Molecular Gastronomy      4.700000
# Japanese Innovative       4.700000
# Japanese Kaiseki          4.700000
# Japanese-Californian      4.700000
# Contemporary Mexican      4.650000
# Avant-garde               4.600000
# ...

# %%
df.columns
# Out:
# Index(['Restaurant_Name', 'City', 'Country', 'Cuisine_Type', 'Michelin_Stars',
#        'Average_Price_USD', 'Chef', 'Established_Year', 'Seating_Capacity',
#        'Rating', 'Signature_Dish', 'Years_Operating', 'Price_Category',
#        'Star_Category', 'Continent'],
#       dtype='object')

# %%
fig = px.bar(df, x="Country", y="Average_Price_USD")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plt.figure(figsize=(20,6))
sns.scatterplot(df, y="Average_Price_USD", x='Years_Operating',hue="Rating",palette="pastel")
# Out:
# <Axes: xlabel='Years_Operating', ylabel='Average_Price_USD'>

# %%
plt.figure(figsize=(20,6))
sns.boxplot(df, x="Continent", y="Michelin_Stars",palette="pastel")
# Out:
# /tmp/ipython-input-4096760709.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# <Axes: xlabel='Continent', ylabel='Michelin_Stars'>

# %%
px.pie(df, names="Chef", values="Rating")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plt.figure(figsize=(10,6))
fig = px.bar(df, x="Cuisine_Type", y="Average_Price_USD")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
